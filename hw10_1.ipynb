# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=30, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/30
# 750/750 [==============================] - 53s 68ms/step - loss: 0.6472 - accuracy: 0.7962 - val_loss: 0.4565 - val_accuracy: 0.8580
# Epoch 2/30
# 750/750 [==============================] - 55s 73ms/step - loss: 0.4096 - accuracy: 0.8725 - val_loss: 0.4105 - val_accuracy: 0.8649
# Epoch 3/30
# 750/750 [==============================] - 54s 72ms/step - loss: 0.3481 - accuracy: 0.8885 - val_loss: 0.3632 - val_accuracy: 0.8841
# Epoch 4/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.3135 - accuracy: 0.8999 - val_loss: 0.3415 - val_accuracy: 0.8897
# Epoch 5/30
# 750/750 [==============================] - 54s 71ms/step - loss: 0.2935 - accuracy: 0.9052 - val_loss: 0.3278 - val_accuracy: 0.8949
# Epoch 6/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.2722 - accuracy: 0.9132 - val_loss: 0.2950 - val_accuracy: 0.9054
# Epoch 7/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.2587 - accuracy: 0.9170 - val_loss: 0.2893 - val_accuracy: 0.9063
# Epoch 8/30
# 750/750 [==============================] - 50s 67ms/step - loss: 0.2440 - accuracy: 0.9228 - val_loss: 0.2763 - val_accuracy: 0.9091
# Epoch 9/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.2289 - accuracy: 0.9288 - val_loss: 0.2937 - val_accuracy: 0.9043
# Epoch 10/30
# 750/750 [==============================] - 50s 67ms/step - loss: 0.2198 - accuracy: 0.9319 - val_loss: 0.2809 - val_accuracy: 0.9127
# Epoch 11/30
# 750/750 [==============================] - 52s 69ms/step - loss: 0.2062 - accuracy: 0.9380 - val_loss: 0.2958 - val_accuracy: 0.9096
# Epoch 12/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.1962 - accuracy: 0.9409 - val_loss: 0.2716 - val_accuracy: 0.9161
# Epoch 13/30
# 750/750 [==============================] - 50s 67ms/step - loss: 0.1869 - accuracy: 0.9446 - val_loss: 0.2850 - val_accuracy: 0.9114
# Epoch 14/30
# 750/750 [==============================] - 48s 65ms/step - loss: 0.1737 - accuracy: 0.9496 - val_loss: 0.2837 - val_accuracy: 0.9109
# Epoch 15/30
# 750/750 [==============================] - 49s 66ms/step - loss: 0.1676 - accuracy: 0.9511 - val_loss: 0.2974 - val_accuracy: 0.9107
# Epoch 16/30
# 750/750 [==============================] - 51s 67ms/step - loss: 0.1574 - accuracy: 0.9551 - val_loss: 0.2949 - val_accuracy: 0.9133
# Epoch 17/30
# 750/750 [==============================] - 50s 66ms/step - loss: 0.1506 - accuracy: 0.9577 - val_loss: 0.3008 - val_accuracy: 0.9137
# Epoch 18/30
# 750/750 [==============================] - 50s 66ms/step - loss: 0.1396 - accuracy: 0.9623 - val_loss: 0.3159 - val_accuracy: 0.9081
# Epoch 19/30
# 750/750 [==============================] - 50s 67ms/step - loss: 0.1353 - accuracy: 0.9626 - val_loss: 0.3063 - val_accuracy: 0.9158
# Epoch 20/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.1280 - accuracy: 0.9664 - val_loss: 0.3243 - val_accuracy: 0.9137
# Epoch 21/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.1207 - accuracy: 0.9683 - val_loss: 0.3424 - val_accuracy: 0.9118
# Epoch 22/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.1140 - accuracy: 0.9712 - val_loss: 0.3466 - val_accuracy: 0.9054
# Epoch 23/30
# 750/750 [==============================] - 52s 70ms/step - loss: 0.1084 - accuracy: 0.9721 - val_loss: 0.3396 - val_accuracy: 0.9104
# Epoch 24/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.1038 - accuracy: 0.9740 - val_loss: 0.3617 - val_accuracy: 0.9053
# Epoch 25/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.1003 - accuracy: 0.9758 - val_loss: 0.3733 - val_accuracy: 0.9120
# Epoch 26/30
# 750/750 [==============================] - 49s 65ms/step - loss: 0.0954 - accuracy: 0.9771 - val_loss: 0.3901 - val_accuracy: 0.9093
# Epoch 27/30
# 750/750 [==============================] - 52s 69ms/step - loss: 0.0935 - accuracy: 0.9776 - val_loss: 0.3771 - val_accuracy: 0.9102
# Epoch 28/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.0884 - accuracy: 0.9800 - val_loss: 0.3803 - val_accuracy: 0.9106
# Epoch 29/30
# 750/750 [==============================] - 51s 68ms/step - loss: 0.0828 - accuracy: 0.9813 - val_loss: 0.4021 - val_accuracy: 0.9112
# Epoch 30/30
# 750/750 [==============================] - 50s 66ms/step - loss: 0.0870 - accuracy: 0.9797 - val_loss: 0.4070 - val_accuracy: 0.9088

# %%
epochs = range(1, 31)
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
predictions = model.predict(test_images)
predicted_labels = tf.argmax(predictions, axis=1).numpy()
true_labels = tf.argmax(test_labels, axis=1).numpy()
# Out:
# 313/313 [==============================] - 5s 13ms/step

# %%
cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
print(classification_report(true_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85      1000
#            1       0.99      0.98      0.99      1000
#            2       0.88      0.84      0.86      1000
#            3       0.89      0.93      0.91      1000
#            4       0.86      0.85      0.85      1000
#            5       0.98      0.97      0.97      1000
#            6       0.71      0.77      0.74      1000
#            7       0.94      0.98      0.96      1000
#            8       0.99      0.96      0.98      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %%
correct_indices = np.where(predicted_labels == true_labels)[0]
incorrect_indices = np.where(predicted_labels != true_labels)[0]

plt.figure(figsize=(15, 7))
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3, 6, 2*i + 1)
    plt.imshow(test_images[correct].reshape(28, 28), cmap='gray', interpolation='none')
    plt.title(f"Predicted: {predicted_labels[correct]}, True: {true_labels[correct]}")
    plt.xticks([])
    plt.yticks([])

for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3, 6, 2*i + 2)
    plt.imshow(test_images[incorrect].reshape(28, 28), cmap='gray', interpolation='none')
    plt.title(f"Predicted: {predicted_labels[incorrect]}, True: {true_labels[incorrect]}")
    plt.xticks([])
    plt.yticks([])

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 6s 18ms/step - loss: 0.4288 - accuracy: 0.9065
# Test accuracy: 0.906499981880188
